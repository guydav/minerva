# %%
from stats import *
# %matplotlib inline

# %%
aggregate_stats(DEFAULT_DATA)
# Out:
# Name                                       Mean    Median  Mode               Variance     Std Dev
# ----------------------------------  -----------  --------  -------------  ------------  ----------
# annual average temperature anomaly     0.584222      0.53  [0.27, 0.37]       0.910442    0.954171
# annual precipitation anomaly           0.878444      0.68  [-0.89, 0.68]      4.13736     2.03405
# cooling degree days anomaly           62.0667       59     [85, 91, 199]  10273         101.356
# heating degree days anomaly         -180.911      -175     All Elements   63533.5       252.058
# Palmer Drought Index anomaly           0.417111      0.52  1.74               5.25893     2.29324
#
# First Variable                      Second Variable                       Pearson's r
# ----------------------------------  ----------------------------------  -------------
# annual average temperature anomaly  heating degree days anomaly            -0.915223
# Palmer Drought Index anomaly        annual precipitation anomaly            0.790753
# cooling degree days anomaly         annual average temperature anomaly      0.735215
# cooling degree days anomaly         heating degree days anomaly            -0.645197
# annual average temperature anomaly  Palmer Drought Index anomaly           -0.540362
# cooling degree days anomaly         Palmer Drought Index anomaly           -0.391564
# Palmer Drought Index anomaly        heating degree days anomaly             0.358639
# annual average temperature anomaly  annual precipitation anomaly           -0.274526
# cooling degree days anomaly         annual precipitation anomaly           -0.154915
# heating degree days anomaly         annual precipitation anomaly            0.0540878

# %%
data_dict = process_data_to_dict(DEFAULT_DATA)
library_test_suite(data_dict)
# Out:
# Std Dev test passed! Max difference = 4.4408920985e-16 <= threshold = 1e-10
# Name                                  My Value    Library Value    Difference
# ----------------------------------  ----------  ---------------  ------------
# cooling degree days anomaly         101.356          101.356      0
# annual average temperature anomaly    0.954171         0.954171   0
# Palmer Drought Index anomaly          2.29324          2.29324    4.44089e-16
# heating degree days anomaly         252.058          252.058      0
# annual precipitation anomaly          2.03405          2.03405    0
#
# Variance test passed! Max difference = 7.27595761418e-12 <= threshold = 1e-10
# Name                                    My Value    Library Value    Difference
# ----------------------------------  ------------  ---------------  ------------
# cooling degree days anomaly         10273            10273          0
# annual average temperature anomaly      0.910442         0.910442   0
# Palmer Drought Index anomaly            5.25893          5.25893    1.77636e-15
# heating degree days anomaly         63533.5          63533.5        7.27596e-12
# annual precipitation anomaly            4.13736          4.13736    0
#
# Median test passed! Max difference = 0.0 <= threshold = 1e-10
# Name                                  My Value    Library Value    Difference
# ----------------------------------  ----------  ---------------  ------------
# cooling degree days anomaly              59               59                0
# annual average temperature anomaly        0.53             0.53             0
# Palmer Drought Index anomaly              0.52             0.52             0
# heating degree days anomaly            -175             -175                0
# annual precipitation anomaly              0.68             0.68             0
#
# Mean test passed! Max difference = 1.66533453694e-16 <= threshold = 1e-10
# Name                                   My Value    Library Value    Difference
# ----------------------------------  -----------  ---------------  ------------
# cooling degree days anomaly           62.0667          62.0667     0
# annual average temperature anomaly     0.584222         0.584222   0
# Palmer Drought Index anomaly           0.417111         0.417111   1.66533e-16
# heating degree days anomaly         -180.911         -180.911      0
# annual precipitation anomaly           0.878444         0.878444   0
#
# Correlation test passed! Max difference = 1.11022302463e-16 <= threshold = 1e-10
# First Variable                      Second Variable                       Pearson's r    Difference
# ----------------------------------  ----------------------------------  -------------  ------------
# annual average temperature anomaly  heating degree days anomaly            -0.915223    0
# Palmer Drought Index anomaly        annual precipitation anomaly            0.790753    0
# cooling degree days anomaly         annual average temperature anomaly      0.735215    0
# cooling degree days anomaly         heating degree days anomaly            -0.645197    0
# annual average temperature anomaly  Palmer Drought Index anomaly           -0.540362    1.11022e-16
# cooling degree days anomaly         Palmer Drought Index anomaly           -0.391564    1.11022e-16
# Palmer Drought Index anomaly        heating degree days anomaly             0.358639    5.55112e-17
# annual average temperature anomaly  annual precipitation anomaly           -0.274526    5.55112e-17
# cooling degree days anomaly         annual precipitation anomaly           -0.154915    5.55112e-17
# heating degree days anomaly         annual precipitation anomaly            0.0540878   4.16334e-17

# %%
histogram('Palmer')

# %%
scatter_plot('precip', 'Palmer')
# Out:
# Correlation test passed!
# Max difference = 2.22044604925e-16 <= threshold = 1e-10
# Name      My Value    Library Value    Difference
# ------  ----------  ---------------  ------------
# m         0.891513         0.891513   1.11022e-16
# b        -0.366033        -0.366033   1.66533e-16
# r         0.790753         0.790753   1.11022e-16
# r^2       0.62529          0.62529    2.22045e-16

# %%
scatter_plot('temperature', 'heating', 'cooling')
# Out:
# Correlation test passed!
# Max difference = 1.11022302463e-16 <= threshold = 1e-10
# Name       My Value    Library Value    Difference
# ------  -----------  ---------------  ------------
# m       -241.77          -241.77       0
# b        -39.6638         -39.6638     0
# r         -0.915223        -0.915223   1.11022e-16
# r^2        0.837634         0.837634   1.11022e-16
#
# Correlation test passed!
# Max difference = 0.0 <= threshold = 1e-10
# Name      My Value    Library Value    Difference
# ------  ----------  ---------------  ------------
# m        78.0973          78.0973               0
# b        16.4405          16.4405               0
# r         0.735215         0.735215             0
# r^2       0.540541         0.540541             0

# %%
kmeans_clustered_statistics(3)
# Out:
# Clustering to 3 clusters...
#
# Printing cluster #0 with 15 elements centered around:
# (annual average temperature anomaly = -3.45e-01, annual precipitation anomaly = 6.93e-01, Palmer Drought Index anomaly = 7.14e-01, cooling degree days anomaly = 5.33e-01, heating degree days anomaly = 8.11e+01)
# Name                                     Mean    Median  Mode             Variance    Std Dev
# ----------------------------------  ---------  --------  ------------  -----------  ---------
# annual average temperature anomaly  -0.344667     -0.41  All Elements     0.258998   0.508919
# annual precipitation anomaly         0.693333      0.39  All Elements     6.48546    2.54666
# cooling degree days anomaly          0.533333      8     All Elements  5178.38      71.961
# heating degree days anomaly         81.1333       38     All Elements  9121.05      95.5042
# Palmer Drought Index anomaly         0.714         0.52  All Elements     4.7293     2.1747
#
# First Variable                      Second Variable                       Pearson's r
# ----------------------------------  ----------------------------------  -------------
# Palmer Drought Index anomaly        annual precipitation anomaly           0.894341
# cooling degree days anomaly         annual average temperature anomaly     0.651365
# annual average temperature anomaly  Palmer Drought Index anomaly          -0.564366
# annual average temperature anomaly  heating degree days anomaly           -0.543195
# annual average temperature anomaly  annual precipitation anomaly          -0.386195
# cooling degree days anomaly         heating degree days anomaly           -0.248767
# cooling degree days anomaly         Palmer Drought Index anomaly          -0.208027
# heating degree days anomaly         annual precipitation anomaly          -0.114717
# cooling degree days anomaly         annual precipitation anomaly          -0.0421357
# Palmer Drought Index anomaly        heating degree days anomaly            0.00511076
#
# Printing cluster #1 with 11 elements centered around:
# (annual average temperature anomaly = 1.77e+00, annual precipitation anomaly = 2.19e-01, Palmer Drought Index anomaly = -1.34e+00, cooling degree days anomaly = 1.79e+02, heating degree days anomaly = -5.22e+02)
# Name                                       Mean    Median  Mode              Variance     Std Dev
# ----------------------------------  -----------  --------  ------------  ------------  ----------
# annual average temperature anomaly     1.77          1.63  All Elements      0.351582    0.592943
# annual precipitation anomaly           0.219091     -0.12  All Elements      3.32201     1.82264
# cooling degree days anomaly          179.455       190     199            4482.25       66.9496
# heating degree days anomaly         -522          -470     All Elements  26809.8       163.737
# Palmer Drought Index anomaly          -1.33545      -0.56  All Elements      2.76044     1.66146
#
# First Variable                      Second Variable                       Pearson's r
# ----------------------------------  ----------------------------------  -------------
# annual average temperature anomaly  heating degree days anomaly           -0.885796
# Palmer Drought Index anomaly        annual precipitation anomaly           0.815655
# annual average temperature anomaly  Palmer Drought Index anomaly          -0.488287
# cooling degree days anomaly         annual average temperature anomaly     0.408706
# annual average temperature anomaly  annual precipitation anomaly          -0.307286
# Palmer Drought Index anomaly        heating degree days anomaly            0.306229
# cooling degree days anomaly         heating degree days anomaly           -0.207093
# cooling degree days anomaly         annual precipitation anomaly          -0.151583
# cooling degree days anomaly         Palmer Drought Index anomaly          -0.14793
# heating degree days anomaly         annual precipitation anomaly           0.00253445
#
# Printing cluster #2 with 19 elements centered around:
# (annual average temperature anomaly = 6.31e-01, annual precipitation anomaly = 1.41e+00, Palmer Drought Index anomaly = 1.20e+00, cooling degree days anomaly = 4.27e+01, heating degree days anomaly = -1.90e+02)
# Name                                       Mean    Median  Mode             Variance    Std Dev
# ----------------------------------  -----------  --------  ------------  -----------  ---------
# annual average temperature anomaly     0.631053      0.58  0.27             0.250873   0.500872
# annual precipitation anomaly           1.40632       1.32  0.68             2.19824    1.48265
# cooling degree days anomaly           42.6842       44     85            6304.74      79.4024
# heating degree days anomaly         -190.316      -181     All Elements  6096.53      78.0803
# Palmer Drought Index anomaly           1.19737       0.91  1.74             4.66692    2.16031
#
# First Variable                      Second Variable                       Pearson's r
# ----------------------------------  ----------------------------------  -------------
# Palmer Drought Index anomaly        annual precipitation anomaly           0.736237
# annual average temperature anomaly  heating degree days anomaly           -0.611991
# annual average temperature anomaly  Palmer Drought Index anomaly          -0.595604
# annual average temperature anomaly  annual precipitation anomaly          -0.514832
# cooling degree days anomaly         annual average temperature anomaly     0.386529
# Palmer Drought Index anomaly        heating degree days anomaly            0.247509
# cooling degree days anomaly         Palmer Drought Index anomaly          -0.184655
# cooling degree days anomaly         annual precipitation anomaly          -0.108621
# cooling degree days anomaly         heating degree days anomaly           -0.104299
# heating degree days anomaly         annual precipitation anomaly           0.00279053
